# %% [markdown]
# <a href="https://colab.research.google.com/github/Ganesh7134/Phonepe_Pulse_Data_Visualization_and_Exploration/blob/main/phonepe_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/PhonePe/pulse.git
# the above url we have got from code part of github
# Out:
# Cloning into 'pulse'...
# remote: Enumerating objects: 8891, done.
# remote: Counting objects: 100% (8891/8891), done.
# remote: Compressing objects: 100% (7400/7400), done.
# remote: Total 8891 (delta 2789), reused 7257 (delta 1170), pack-reused 0
# Receiving objects: 100% (8891/8891), 2.30 MiB | 5.66 MiB/s, done.
# Resolving deltas: 100% (2789/2789), done.

# %%
#Once created the clone of GIT-HUB repository then,
#Required libraries for the program

import pandas as pd
import json
import os

#This is to direct the path to get the data as states

path="/content/pulse/data/aggregated/transaction/country/india/state/"
Agg_state_list=os.listdir(path)
Agg_state_list
#Agg_state_list--> to get the list of states in India

#<------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------>#

#This is to extract the data's to create a dataframe

clm={'State':[], 'Year':[],'Quater':[],'Transacion_type':[], 'Transacion_count':[], 'Transacion_amount':[]}
for i in Agg_state_list:
    p_i=path+i+"/"
    Agg_yr=os.listdir(p_i)
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            print(D)
            for z in D['data']['transactionData']:
              Name=z['name']
              count=z['paymentInstruments'][0]['count']
              amount=z['paymentInstruments'][0]['amount']
              clm['Transacion_type'].append(Name)
              clm['Transacion_count'].append(count)
              clm['Transacion_amount'].append(amount)
              clm['State'].append(i)
              clm['Year'].append(j)
              clm['Quater'].append(int(k.strip('.json'))) # here we strip .json from the name and convert into integer
#Succesfully created a dataframe
Agg_Trans=pd.DataFrame(clm)
# Out:
# {'success': True, 'code': 'SUCCESS', 'data': {'from': 1530383400000, 'to': 1538073000000, 'transactionData': [{'name': 'Peer-to-peer payments', 'paymentInstruments': [{'type': 'TOTAL', 'count': 41882429, 'amount': 38439798815.23789}]}, {'name': 'Recharge & bill payments', 'paymentInstruments': [{'type': 'TOTAL', 'count': 7596315, 'amount': 1992473341.2750623}]}, {'name': 'Merchant payments', 'paymentInstruments': [{'type': 'TOTAL', 'count': 2252265, 'amount': 979603555.1397107}]}, {'name': 'Financial Services', 'paymentInstruments': [{'type': 'TOTAL', 'count': 1619524, 'amount': 185187032.8965006}]}, {'name': 'Others', 'paymentInstruments': [{'type': 'TOTAL', 'count': 354883, 'amount': 246871438.6293067}]}]}, 'responseTimestamp': 1630501489339}
# ...

# %%
Agg_Trans.to_csv("Aggregated_transactions.csv",index = False)

# %%
#This is to direct the path to get the data as states

path="/content/pulse/data/aggregated/user/country/india/state/"
Agg_state_list=os.listdir(path)
print(Agg_state_list)
#Agg_state_list--> to get the list of states in India

#<------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------>#

#This is to extract the data's to create a dataframe

clm={'State':[], 'Year':[],'Quater':[],'registered_users':[], 'Brand':[], 'count':[],'percentage':[],'appOpens':[]}
for i in Agg_state_list:
    p_i=path+i+"/"
    Agg_yr=os.listdir(p_i)
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            if D["data"]["usersByDevice"] is not None:
              # print(D)
              clm["registered_users"].append(D["data"]["aggregated"]["registeredUsers"])
              clm["appOpens"].append(D["data"]["aggregated"]["appOpens"])
              clm["Brand"].append(D["data"]["usersByDevice"][0]["brand"])
              clm["count"].append(D["data"]["usersByDevice"][0]["count"])
              clm["percentage"].append(D["data"]["usersByDevice"][0]["percentage"])
              clm['State'].append(i)
              clm['Year'].append(j)
              clm['Quater'].append(int(k.strip('.json')))

Agg_User=pd.DataFrame(clm)
# Out:
# ['lakshadweep', 'andhra-pradesh', 'delhi', 'manipur', 'sikkim', 'bihar', 'west-bengal', 'gujarat', 'himachal-pradesh', 'chandigarh', 'dadra-&-nagar-haveli-&-daman-&-diu', 'haryana', 'andaman-&-nicobar-islands', 'tamil-nadu', 'uttarakhand', 'arunachal-pradesh', 'odisha', 'jharkhand', 'nagaland', 'maharashtra', 'telangana', 'puducherry', 'chhattisgarh', 'jammu-&-kashmir', 'mizoram', 'kerala', 'uttar-pradesh', 'madhya-pradesh', 'goa', 'karnataka', 'rajasthan', 'meghalaya', 'punjab', 'assam', 'ladakh', 'tripura']

# %%
for i in Agg_state_list:
  print(i)
# Out:
# lakshadweep
# andhra-pradesh
# delhi
# manipur
# sikkim
# bihar
# west-bengal
# gujarat
# himachal-pradesh
# chandigarh
# dadra-&-nagar-haveli-&-daman-&-diu
# haryana
# andaman-&-nicobar-islands
# tamil-nadu
# uttarakhand
# arunachal-pradesh
# odisha
# jharkhand
# nagaland
# maharashtra
# telangana
# puducherry
# chhattisgarh
# jammu-&-kashmir
# mizoram
# kerala
# uttar-pradesh
# madhya-pradesh
# goa
# karnataka
# rajasthan
# meghalaya
# punjab
# assam
# ladakh
# tripura

# %%
Agg_User
# Out:
#            State  Year  Quater  registered_users    Brand   count  percentage  \
# 0    lakshadweep  2018       1               501  Samsung     102    0.203593
# 1    lakshadweep  2018       2               686   Xiaomi     147    0.214286
# 2    lakshadweep  2018       4              1156   Xiaomi     245    0.211938
# 3    lakshadweep  2018       3               918   Xiaomi     195    0.212418
# 4    lakshadweep  2021       1              4577     Vivo    1032    0.225475
# ..           ...   ...     ...               ...      ...     ...         ...
# 607      tripura  2019       3            245456   Xiaomi   61894    0.252159
# 608      tripura  2020       1            299962   Xiaomi   75081    0.250302
# 609      tripura  2020       2            336666   Xiaomi   83763    0.248801
# 610      tripura  2020       4            409110   Xiaomi  101066    0.247039
# 611      tripura  2020       3            376731   Xiaomi   93468    0.248103
#
#      appOpens
# 0           0
# ...

# %%
Agg_User['registered_users_count'] = Agg_User['registered_users'] / 1000000.0

# %%
Agg_User = Agg_User.drop('registered_users_count', axis=1)

# %%
import numpy as np
modified_r = []
for i in Agg_User["registered_users"]:
  modified_r.append(np.log10(i))

# %%
Agg_User['Modified_registered_users'] = modified_r

# %%
Agg_User.to_csv("Aggregate_Users.csv")

# %%
df = pd.read_csv("Aggregate_Users.csv")
df
# Out:
#      Unnamed: 0        State  Year  Quater  registered_users    Brand   count  \
# 0             0  lakshadweep  2018       1               501  Samsung     102
# 1             1  lakshadweep  2018       2               686   Xiaomi     147
# 2             2  lakshadweep  2018       4              1156   Xiaomi     245
# 3             3  lakshadweep  2018       3               918   Xiaomi     195
# 4             4  lakshadweep  2021       1              4577     Vivo    1032
# ..          ...          ...   ...     ...               ...      ...     ...
# 607         607      tripura  2019       3            245456   Xiaomi   61894
# 608         608      tripura  2020       1            299962   Xiaomi   75081
# 609         609      tripura  2020       2            336666   Xiaomi   83763
# 610         610      tripura  2020       4            409110   Xiaomi  101066
# 611         611      tripura  2020       3            376731   Xiaomi   93468
#
# ...

# %%
grouped_df1 = Agg_User.groupby(['State', 'Brand'])['registered_users'].sum()

# %%
grouped_df2 = Agg_User.groupby(['State','Year', 'Quater'])['Modified_registered_users'].sum()

# %%
grouped_df3 = Agg_User.groupby('Brand')['registered_users'].sum()

# %%
grouped_df2
# Out:
# State                      Year  Quater
# andaman-&-nicobar-islands  2018  1         3.828660
#                                  2         3.973359
#                                  3         4.084541
#                                  4         4.182472
#                            2019  1         4.269420
#                                              ...
# west-bengal                2021  1         7.225537
#                                  2         7.254789
#                                  3         7.286081
#                                  4         7.314805
#                            2022  1         7.340836
# Name: Modified_registered_users, Length: 612, dtype: float64

# %%
Agg_User.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 612 entries, 0 to 611
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   State                      612 non-null    object
#  1   Year                       612 non-null    object
#  2   Quater                     612 non-null    int64
#  3   registered_users           612 non-null    int64
#  4   Brand                      612 non-null    object
#  5   count                      612 non-null    int64
#  6   percentage                 612 non-null    float64
#  7   appOpens                   612 non-null    int64
#  8   Modified_registered_users  612 non-null    float64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 43.2+ KB

# %%
Agg_User.isnull().sum()
# Out:
# State                        0
# Year                         0
# Quater                       0
# registered_users             0
# Brand                        0
# count                        0
# percentage                   0
# appOpens                     0
# Modified_registered_users    0
# dtype: int64

# %%
path="/content/pulse/data/map/transaction/hover/country/india/state/"
Agg_state_list=os.listdir(path)
Agg_state_list
#Agg_state_list--> to get the list of states in India

#<------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------>#

#This is to extract the data's to create a dataframe

clm={'State':[],'District_name':[], 'Type_of_metrics':[],'Transaction_count':[],'Transaction_amount':[]}
for i in Agg_state_list:
    p_i=path+i+"/"
    Agg_yr=os.listdir(p_i)
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            # print(D)
#             # print(D["data"])
            clm['District_name'].append(D["data"]["hoverDataList"][0]["name"])
            clm['Type_of_metrics'].append(D["data"]["hoverDataList"][0]["metric"][0]["type"])
            clm['Transaction_count'].append(D["data"]["hoverDataList"][0]["metric"][0]["count"])
            clm['Transaction_amount'].append(D["data"]["hoverDataList"][0]["metric"][0]["amount"])
            clm['State'].append(i)
Map_transaction = pd.DataFrame(clm)

# %%
Map_transaction
# Out:
#            State         District_name Type_of_metrics  Transaction_count  \
# 0    lakshadweep  lakshadweep district           TOTAL                778
# 1    lakshadweep  lakshadweep district           TOTAL               2132
# 2    lakshadweep  lakshadweep district           TOTAL               1642
# 3    lakshadweep  lakshadweep district           TOTAL               1703
# 4    lakshadweep  lakshadweep district           TOTAL               9085
# ..           ...                   ...             ...                ...
# 787      tripura      unakoti district           TOTAL              51385
# 788      tripura      unakoti district           TOTAL              77102
# 789      tripura      unakoti district           TOTAL              63441
# 790      tripura      unakoti district           TOTAL             402005
# 791      tripura      unakoti district           TOTAL             461521
#
#      Transaction_amount
# 0          1.928611e+06
# 1          6.187810e+06
# ...

# %%
Upd = []
for i in Map_transaction["Transaction_amount"]:
  Upd.append(np.log(i))

# %%
Map_transaction["Updated_Transaction_amount"] = Upd

# %%
Upd = []
for i in Map_transaction["Transaction_count"]:
  Upd.append(np.log(i))

# %%
Map_transaction["Updated_Transaction_count"] = Upd

# %%
Map_transaction
# Out:
#            State         District_name Type_of_metrics  Transaction_count  \
# 0    lakshadweep  lakshadweep district           TOTAL                778
# 1    lakshadweep  lakshadweep district           TOTAL               2132
# 2    lakshadweep  lakshadweep district           TOTAL               1642
# 3    lakshadweep  lakshadweep district           TOTAL               1703
# 4    lakshadweep  lakshadweep district           TOTAL               9085
# ..           ...                   ...             ...                ...
# 787      tripura      unakoti district           TOTAL              51385
# 788      tripura      unakoti district           TOTAL              77102
# 789      tripura      unakoti district           TOTAL              63441
# 790      tripura      unakoti district           TOTAL             402005
# 791      tripura      unakoti district           TOTAL             461521
#
#      Transaction_amount  Updated_Transaction_amount  Updated_Transaction_count
# ...

# %%
Map_transaction.to_csv("Map_transaction.csv")

# %%
D_list = list(Map_transaction["District_name"].unique())

# %%
D_list
# Out:
# ['lakshadweep district',
#  'east godavari district',
#  'south district',
#  'kangpokpi district',
#  'madhepura district',
#  'south twenty four parganas district',
#  'anand district',
#  'solan district',
#  'chandigarh district',
#  'diu district',
#  'yamunanagar district',
#  'north and middle andaman district',
#  'tiruchirappalli district',
#  'bageshwar district',
#  'lower dibang valley district',
#  'rayagada district',
#  'ramgarh district',
#  'mon district',
#  'jalgaon district',
#  'narayanpet district',
#  'karaikal district',
#  'dhamtari district',
#  'muzaffarabad district',
#  'serchhip district',
#  'thiruvananthapuram district',
#  'amethi district',
#  'morena district',
#  'north goa district',
#  'mysuru district',
#  'pali district',
#  'north garo hills district',
#  'shahid bhagat singh nagar district',
#  'tinsukia district',
#  'kargil district',
#  'unakoti district']

# %%
path="/content/pulse/data/map/user/hover/country/india/state/"
Agg_state_list=os.listdir(path)
Agg_state_list
#Agg_state_list--> to get the list of states in India

#<------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------>#

#This is to extract the data's to create a dataframe

clm={'State':[],'District_name':[], "Year":[] , "Quater":[],"registeredUser":[],"appOpens":[]}
for i in Agg_state_list:
    p_i=path+i+"/"
    Agg_yr=os.listdir(p_i)
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            # print(D)
            for dist,reg in D["data"]["hoverData"].items():
              clm["registeredUser"].append(reg["registeredUsers"])
              clm["appOpens"].append(reg["appOpens"])
              clm["District_name"].append(dist)
              clm["State"].append(i)
              clm["Year"].append(j)
              clm['Quater'].append(int(k.strip('.json')))
Map_user = pd.DataFrame(clm)

# %%
Map_user
# Out:
#              State           District_name  Year  Quater  registeredUser  \
# 0      lakshadweep    lakshadweep district  2018       1             501
# 1      lakshadweep    lakshadweep district  2018       2             686
# 2      lakshadweep    lakshadweep district  2018       4            1156
# 3      lakshadweep    lakshadweep district  2018       3             918
# 4      lakshadweep    lakshadweep district  2021       1            4577
# ...            ...                     ...   ...     ...             ...
# 16099      tripura  north tripura district  2023       2           74840
# 16100      tripura         dhalai district  2023       2           59728
# 16101      tripura  south tripura district  2023       2           80248
# 16102      tripura         gomati district  2023       2           68250
# 16103      tripura   west tripura district  2023       2          291531
#
#        appOpens
# 0             0
# 1             0
# 2             0
# 3             0
# ...

# %%
upd = []
for i in Map_user["registeredUser"]:
  upd.append(np.log(i))

# %%
Map_user["Updated_registeredUser"] = upd

# %%
upd = []
for i in Map_user["appOpens"]:
  if i == 0:
    upd.append(i)
  elif i != 0:
    upd.append(np.log(i))

# %%
Map_user["Updated_appOpens"] = upd

# %%
Map_user
# Out:
#              State           District_name  Year  Quater  registeredUser  \
# 0      lakshadweep    lakshadweep district  2018       1             501
# 1      lakshadweep    lakshadweep district  2018       2             686
# 2      lakshadweep    lakshadweep district  2018       4            1156
# 3      lakshadweep    lakshadweep district  2018       3             918
# 4      lakshadweep    lakshadweep district  2021       1            4577
# ...            ...                     ...   ...     ...             ...
# 16099      tripura  north tripura district  2023       2           74840
# 16100      tripura         dhalai district  2023       2           59728
# 16101      tripura  south tripura district  2023       2           80248
# 16102      tripura         gomati district  2023       2           68250
# 16103      tripura   west tripura district  2023       2          291531
#
#        appOpens  Updated_registeredUser  Updated_appOpens
# ...

# %%
Map_user.to_csv("Map_user.csv")

# %%
path="/content/pulse/data/top/transaction/country/india/state/"
Agg_state_list=os.listdir(path)
Agg_state_list
#Agg_state_list--> to get the list of states in India

#<------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------>#

#This is to extract the data's to create a dataframe

clm={'State':[],'District_name':[], 'Type_of_metrics':[],'Transaction_count':[],'Transaction_amount':[]}
for i in Agg_state_list:
    p_i=path+i+"/"
    Agg_yr=os.listdir(p_i)
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            clm["State"].append(i)
            clm["District_name"].append(D["data"]['districts'][0]['entityName'])
            clm['Type_of_metrics'].append(D["data"]['districts'][0]['metric']["type"])
            clm['Transaction_count'].append(D["data"]['districts'][0]['metric']["count"])
            clm['Transaction_amount'].append(D["data"]['districts'][0]['metric']["amount"])
Top_transaction = pd.DataFrame(clm)

# %%
Top_transaction
# Out:
#            State District_name Type_of_metrics  Transaction_count  \
# 0    lakshadweep   lakshadweep           TOTAL                778
# 1    lakshadweep   lakshadweep           TOTAL               2132
# 2    lakshadweep   lakshadweep           TOTAL               1642
# 3    lakshadweep   lakshadweep           TOTAL               1703
# 4    lakshadweep   lakshadweep           TOTAL               9085
# ..           ...           ...             ...                ...
# 787      tripura  west tripura           TOTAL             422021
# 788      tripura  west tripura           TOTAL             692509
# 789      tripura  west tripura           TOTAL             522218
# 790      tripura  west tripura           TOTAL            3134574
# 791      tripura  west tripura           TOTAL            3504788
#
#      Transaction_amount
# 0          1.928611e+06
# 1          6.187810e+06
# 2          4.463214e+06
# 3          4.339032e+06
# 4          2.704278e+07
# ...

# %%
Upd = []
for i in Top_transaction["Transaction_amount"]:
  Upd.append(np.log(i))

# %%
Top_transaction["Updated_Transaction_amount"] = Upd

# %%
Top_transaction
# Out:
#            State District_name Type_of_metrics  Transaction_count  \
# 0    lakshadweep   lakshadweep           TOTAL                778
# 1    lakshadweep   lakshadweep           TOTAL               2132
# 2    lakshadweep   lakshadweep           TOTAL               1642
# 3    lakshadweep   lakshadweep           TOTAL               1703
# 4    lakshadweep   lakshadweep           TOTAL               9085
# ..           ...           ...             ...                ...
# 787      tripura  west tripura           TOTAL             422021
# 788      tripura  west tripura           TOTAL             692509
# 789      tripura  west tripura           TOTAL             522218
# 790      tripura  west tripura           TOTAL            3134574
# 791      tripura  west tripura           TOTAL            3504788
#
#      Transaction_amount  Updated_Transaction_amount
# 0          1.928611e+06                   14.472311
# 1          6.187810e+06                   15.638092
# ...

# %%
Upd = []
for i in Top_transaction["Transaction_count"]:
  Upd.append(np.log(i))

# %%
Top_transaction["Updated_Transaction_count"] = Upd

# %%
Top_transaction
# Out:
#            State District_name Type_of_metrics  Transaction_count  \
# 0    lakshadweep   lakshadweep           TOTAL                778
# 1    lakshadweep   lakshadweep           TOTAL               2132
# 2    lakshadweep   lakshadweep           TOTAL               1642
# 3    lakshadweep   lakshadweep           TOTAL               1703
# 4    lakshadweep   lakshadweep           TOTAL               9085
# ..           ...           ...             ...                ...
# 787      tripura  west tripura           TOTAL             422021
# 788      tripura  west tripura           TOTAL             692509
# 789      tripura  west tripura           TOTAL             522218
# 790      tripura  west tripura           TOTAL            3134574
# 791      tripura  west tripura           TOTAL            3504788
#
#      Transaction_amount  Updated_Transaction_amount  Updated_Transaction_count
# 0          1.928611e+06                   14.472311                   6.656727
# ...

# %%
Top_transaction.to_csv("Top_transactions.csv")

# %%
path="/content/pulse/data/top/user/country/india/state/"
Agg_state_list=os.listdir(path)
Agg_state_list
#Agg_state_list--> to get the list of states in India

#<------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------>#

#This is to extract the data's to create a dataframe

clm={'State':[],'District_name':[],'Year':[],'Quater':[],'registeredUsers':[]}
for i in Agg_state_list:
    p_i=path+i+"/"
    Agg_yr=os.listdir(p_i)
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            # print(D)
            clm["State"].append(i)
            clm["Year"].append(j)
            clm['Quater'].append(int(k.strip('.json')))
            clm["District_name"].append(D["data"]['districts'][0]['name'])
            clm["registeredUsers"].append(D["data"]['districts'][0]['registeredUsers'])
Top_users = pd.DataFrame(clm)

# %%
Top_users
# Out:
#            State District_name  Year  Quater  registeredUsers
# 0    lakshadweep   lakshadweep  2018       1              501
# 1    lakshadweep   lakshadweep  2018       2              686
# 2    lakshadweep   lakshadweep  2018       4             1156
# 3    lakshadweep   lakshadweep  2018       3              918
# 4    lakshadweep   lakshadweep  2021       1             4577
# ..           ...           ...   ...     ...              ...
# 787      tripura  west tripura  2020       2           137156
# 788      tripura  west tripura  2020       4           163752
# 789      tripura  west tripura  2020       3           151432
# 790      tripura  west tripura  2023       1           280021
# 791      tripura  west tripura  2023       2           291531
#
# [792 rows x 5 columns]

# %%
Top_users.to_csv("Top_users.csv")

# %%
import json

# Define the JSON data
json_data = {
    "success": True,
    "code": "SUCCESS",
    "data": {
        "aggregated": {
            "registeredUsers": 6740,
            "appOpens": 0
        },
        "usersByDevice": [{
            "brand": "Xiaomi",
            "count": 1665,
            "percentage": 0.2470326409495549
        }, {
            "brand": "Samsung",
            "count": 1445,
            "percentage": 0.21439169139465875
        }, {
            "brand": "Vivo",
            "count": 982,
            "percentage": 0.1456973293768546
        }, {
            "brand": "Oppo",
            "count": 501,
            "percentage": 0.07433234421364986
        }, {
            "brand": "OnePlus",
            "count": 332,
            "percentage": 0.04925816023738872
        }, {
            "brand": "Realme",
            "count": 316,
            "percentage": 0.04688427299703264
        }, {
            "brand": "Apple",
            "count": 229,
            "percentage": 0.03397626112759644
        }, {
            "brand": "Motorola",
            "count": 226,
            "percentage": 0.03353115727002967
        }, {
            "brand": "Lenovo",
            "count": 202,
            "percentage": 0.02997032640949555
        }, {
            "brand": "Huawei",
            "count": 158,
            "percentage": 0.02344213649851632
        }, {
            "brand": "Others",
            "count": 684,
            "percentage": 0.10148367952522255
        }]
    },
    "responseTimestamp": 1630501494543
}

# Extract the registeredUsers from the aggregated data
registered_users = json_data["data"]["aggregated"]["registeredUsers"]

# Print the registeredUsers
print(registered_users)
# Out:
# 6740

# %%
df = pd.read_csv("Aggregated_transactions.csv")

# %%
df
# Out:
#             State  Year  Quater           Transacion_type  Transacion_count  \
# 0     lakshadweep  2018       1     Peer-to-peer payments               423
# 1     lakshadweep  2018       1  Recharge & bill payments               342
# 2     lakshadweep  2018       1         Merchant payments                 5
# 3     lakshadweep  2018       1                    Others                 8
# 4     lakshadweep  2018       2     Peer-to-peer payments              1315
# ...           ...   ...     ...                       ...               ...
# 3949      tripura  2023       2         Merchant payments           3654027
# 3950      tripura  2023       2     Peer-to-peer payments           3144448
# 3951      tripura  2023       2  Recharge & bill payments           1112236
# 3952      tripura  2023       2        Financial Services              8100
# 3953      tripura  2023       2                    Others             10732
#
#       Transacion_amount
# 0          1.860278e+06
# ...

# %%
df["Transacion_amount"] = df["Transacion_amount"].astype("int64")

# %%
df.rename(columns={'Transacion_amount': 'Transaction_Amount',"Transacion_type":"Transaction_type","Transacion_count":"Transaction_count"}, inplace=True)

# %%
df.to_csv("Aggregated_transactions.csv")

# %%
# !pip install Babel

# %%
from babel.numbers import format_currency

# %%
updated_trans = []
for i in df["Transaction_Amount"]:
  updated_trans.append(format_currency(i, 'INR', locale='en_IN'))

# %%
df["updated_transaction_amount"] = updated_trans

# %%
df
# Out:
#             State  Year  Quater          Transaction_type  Transaction_count  \
# 0     lakshadweep  2018       1     Peer-to-peer payments                423
# 1     lakshadweep  2018       1  Recharge & bill payments                342
# 2     lakshadweep  2018       1         Merchant payments                  5
# 3     lakshadweep  2018       1                    Others                  8
# 4     lakshadweep  2018       2     Peer-to-peer payments               1315
# ...           ...   ...     ...                       ...                ...
# 3949      tripura  2023       2         Merchant payments            3654027
# 3950      tripura  2023       2     Peer-to-peer payments            3144448
# 3951      tripura  2023       2  Recharge & bill payments            1112236
# 3952      tripura  2023       2        Financial Services               8100
# 3953      tripura  2023       2                    Others              10732
#
# ...

# %%
df_grouped = df.groupby(['Year', 'Quater'])
Demo = list(df_grouped)

# %%
df_grouped = df.groupby(['State','Year', 'Quater',"Transaction_type"])['Transaction_Amount'].sum().reset_index()

# %%
df_grouped.head(25)
# Out:
#                         State  Year  Quater          Transaction_type  \
# 0   andaman-&-nicobar-islands  2018       1        Financial Services
# 1   andaman-&-nicobar-islands  2018       1         Merchant payments
# 2   andaman-&-nicobar-islands  2018       1                    Others
# 3   andaman-&-nicobar-islands  2018       1     Peer-to-peer payments
# 4   andaman-&-nicobar-islands  2018       1  Recharge & bill payments
# 5   andaman-&-nicobar-islands  2018       2        Financial Services
# 6   andaman-&-nicobar-islands  2018       2         Merchant payments
# 7   andaman-&-nicobar-islands  2018       2                    Others
# 8   andaman-&-nicobar-islands  2018       2     Peer-to-peer payments
# 9   andaman-&-nicobar-islands  2018       2  Recharge & bill payments
# 10  andaman-&-nicobar-islands  2018       3        Financial Services
# 11  andaman-&-nicobar-islands  2018       3         Merchant payments
# ...

# %%
data_amount = df.groupby(['State'])['Transaction_Amount'].sum().reset_index()
data_count = df.groupby(['State'])['Transaction_count'].sum().reset_index()

# %%
data_amount
# Out:
#                                  State  Transaction_Amount
# 0            andaman-&-nicobar-islands         28446581857
# 1                       andhra-pradesh      16339842112586
# 2                    arunachal-pradesh        106743520036
# 3                                assam       1548293213867
# 4                                bihar       7914668793994
# 5                           chandigarh        188038858249
# 6                         chhattisgarh       2102595782665
# 7   dadra-&-nagar-haveli-&-daman-&-diu         83707688653
# 8                                delhi       6384975701344
# 9                                  goa        234075461304
# 10                             gujarat       4868271186175
# 11                             haryana       4517875241440
# 12                    himachal-pradesh        369315630618
# 13                     jammu-&-kashmir        477152874771
# 14                           jharkhand       2495785385478
# ...

# %%
data_amount = df.groupby(['Year'])['Transaction_Amount'].sum().reset_index()

# %%
data_amount
# Out:
#    Year  Transaction_Amount
# 0  2018       1623045396048
# 1  2019       6276688132817
# 2  2020      14641161977712
# 3  2021      34598699686820
# 4  2022      64266332910550
# 5  2023      43432452307247

# %%
year_and_quarter_group = []
for i in range(0,len(Demo)-4+1,4):
  year_and_quarter_group.append(Demo[i:i+4])

# %%
year_and_quarter_group.extend([Demo[-2],Demo[-1]])

# %%
# H = year_and_quarter_group[0][3][1]
year_and_quarter_group
# Out:
# [[((2018, 1),
#                   State  Year  Quater          Transaction_type  \
#    0        lakshadweep  2018       1     Peer-to-peer payments
#    1        lakshadweep  2018       1  Recharge & bill payments
#    2        lakshadweep  2018       1         Merchant payments
#    3        lakshadweep  2018       1                    Others
#    104   andhra-pradesh  2018       1  Recharge & bill payments
#    ...              ...   ...     ...                       ...
#    3844         tripura  2018       1  Recharge & bill payments
#    3845         tripura  2018       1     Peer-to-peer payments
#    3846         tripura  2018       1        Financial Services
#    3847         tripura  2018       1         Merchant payments
#    3848         tripura  2018       1                    Others
#
#          Transaction_count  Transaction_Amount updated_transaction_amount
#    0                   423             1860278              ₹18,60,278.00
# ...

# %%
Transaction_count = []
for i in df["Transaction_count"]:
  numbers = "{:,}".format(i)
  Transaction_count.append(numbers)

# %%
df["updated_transaction_count"] = Transaction_count

# %%
df
# Out:
#             State  Year  Quater          Transaction_type  Transaction_count  \
# 0     lakshadweep  2018       1     Peer-to-peer payments                423
# 1     lakshadweep  2018       1  Recharge & bill payments                342
# 2     lakshadweep  2018       1         Merchant payments                  5
# 3     lakshadweep  2018       1                    Others                  8
# 4     lakshadweep  2018       2     Peer-to-peer payments               1315
# ...           ...   ...     ...                       ...                ...
# 3949      tripura  2023       2         Merchant payments            3654027
# 3950      tripura  2023       2     Peer-to-peer payments            3144448
# 3951      tripura  2023       2  Recharge & bill payments            1112236
# 3952      tripura  2023       2        Financial Services               8100
# 3953      tripura  2023       2                    Others              10732
#
# ...

# %%
df.isnull().sum()
# Out:
# State                         0
# Year                          0
# Quater                        0
# Transaction_type              0
# Transaction_count             0
# Transaction_Amount            0
# updated_transaction_amount    0
# updated_transaction_count     0
# dtype: int64

# %%
df["Transaction_Amount"].mean()
# Out:
# 41689018819.21953

# %%
numerator = df["Transaction_Amount"].sum()
denominator = len(df["Transaction_Amount"])
value = numerator//denominator

# %%
average_transaction_amount_Aggregated_TRansaction = format_currency(value, 'INR', locale='en_IN')

# %%
average_transaction_amount_Aggregated_TRansaction
# Out:
# '₹41,68,90,18,819.00'

# %%
df["Transaction_type"].unique()
# Out:
# array(['Peer-to-peer payments', 'Recharge & bill payments',
#        'Merchant payments', 'Others', 'Financial Services'], dtype=object)

# %%
res = df["Transaction_type"].value_counts()
res
# Out:
# Peer-to-peer payments       792
# Recharge & bill payments    792
# Merchant payments           792
# Others                      792
# Financial Services          786
# Name: Transaction_type, dtype: int64

# %%
res = df.groupby("Transaction_type").Transaction_Amount.value_counts()

# %%
res
# Out:
# Transaction_type          Transaction_Amount
# Financial Services        34                    1
#                           389                   1
#                           1481                  1
#                           9134                  1
#                           10601                 1
#                                                ..
# Recharge & bill payments  92136759501           1
#                           102787343319          1
#                           104828264973          1
#                           112036624317          1
#                           112846643294          1
# Name: Transaction_Amount, Length: 3954, dtype: int64

# %%
# df = df.set_index('State')

# # Select all rows and columns using `df.loc`
# all_details = df.loc[:, :]

# # Print the all_details DataFrame
# # print(all_details)

# %%
li_states = list(df["State"].unique())
li_states
# average = df["Transacion_count"].mean()
# Out:
# ['lakshadweep',
#  'andhra-pradesh',
#  'delhi',
#  'manipur',
#  'sikkim',
#  'bihar',
#  'west-bengal',
#  'gujarat',
#  'himachal-pradesh',
#  'chandigarh',
#  'dadra-&-nagar-haveli-&-daman-&-diu',
#  'haryana',
#  'andaman-&-nicobar-islands',
#  'tamil-nadu',
#  'uttarakhand',
#  'arunachal-pradesh',
#  'odisha',
#  'jharkhand',
#  'nagaland',
#  'maharashtra',
#  'telangana',
#  'puducherry',
#  'chhattisgarh',
#  'jammu-&-kashmir',
#  'mizoram',
#  'kerala',
#  'uttar-pradesh',
#  'madhya-pradesh',
#  'goa',
#  'karnataka',
#  'rajasthan',
#  'meghalaya',
#  'punjab',
#  'assam',
#  'ladakh',
#  'tripura']

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Read the CSV file into a Pandas DataFrame
df = pd.read_csv("Aggregated_transactions.csv", index_col="State")

# Get the transaction count based on state
transaction_count_by_state = df.groupby("State")["Transaction_count"].sum()

# Create a bar chart of the transaction count based on state
plt.figure(figsize=(10, 6))
transaction_count_by_state.plot(kind="bar")

# Set the chart title and axis labels
plt.title("Transaction Count by State")
plt.xlabel("State")
plt.ylabel("Transaction Count")

# Rotate the x-axis labels to prevent overlapping
plt.xticks(rotation=45)

# Display the chart
plt.show()

# %%
# df["Transaction_type"].value_counts()

# %%
grouped_df = df.groupby('Transaction_type')['Transaction_Amount'].sum()

# %%
grouped_df.to_dict()
# Out:
# {'Financial Services': 61547960876,
#  'Merchant payments': 27256086952261,
#  'Others': 129064736143,
#  'Peer-to-peer payments': 130908214799672,
#  'Recharge & bill payments': 6483465962242}

# %% [markdown]
# ##**chloropet map using plotly**

# %%
H = year_and_quarter_group[0][0][1]

# %%
H
# Out:
#                State  Year  Quater          Transaction_type  \
# 0        lakshadweep  2018       1     Peer-to-peer payments
# 1        lakshadweep  2018       1  Recharge & bill payments
# 2        lakshadweep  2018       1         Merchant payments
# 3        lakshadweep  2018       1                    Others
# 104   andhra-pradesh  2018       1  Recharge & bill payments
# ...              ...   ...     ...                       ...
# 3844         tripura  2018       1  Recharge & bill payments
# 3845         tripura  2018       1     Peer-to-peer payments
# 3846         tripura  2018       1        Financial Services
# 3847         tripura  2018       1         Merchant payments
# 3848         tripura  2018       1                    Others
#
#       Transaction_count  Transaction_Amount updated_transaction_amount
# 0                   423             1860278              ₹18,60,278.00
# 1                   342               61432                 ₹61,432.00
# ...

# %%
data_amount = df.groupby(['State'])['Transaction_Amount'].sum().reset_index()

# %%
data_amount
# Out:
#                                  State  Transaction_Amount
# 0            andaman-&-nicobar-islands         28446581857
# 1                       andhra-pradesh      16339842112586
# 2                    arunachal-pradesh        106743520036
# 3                                assam       1548293213867
# 4                                bihar       7914668793994
# 5                           chandigarh        188038858249
# 6                         chhattisgarh       2102595782665
# 7   dadra-&-nagar-haveli-&-daman-&-diu         83707688653
# 8                                delhi       6384975701344
# 9                                  goa        234075461304
# 10                             gujarat       4868271186175
# 11                             haryana       4517875241440
# 12                    himachal-pradesh        369315630618
# 13                     jammu-&-kashmir        477152874771
# 14                           jharkhand       2495785385478
# ...

# %%
state_names = {"andaman-&-nicobar-islands":"Andaman & Nicobar",
               "andhra-pradesh":"Andhra Pradesh",
               "arunachal-pradesh":"Arunachal Pradesh",
               "assam":"Assam",
               "bihar":"Bihar",
               "chandigarh":"Chandigarh",
               "chhattisgarh":"Chhattisgarh",
               "dadra-&-nagar-haveli-&-daman-&-diu":"Dadra and Nagar Haveli and Daman and Diu",
               "delhi":"Delhi",
               "goa":"Goa",
               "gujarat":"Gujarat",
               "haryana":"Haryana",
               "himachal-pradesh":"Himachal Pradesh",
               "jammu-&-kashmir":"Jammu & Kashmir",
               "jharkhand":"Jharkhand",
               "karnataka":"Karnataka",
               "kerala":"Kerala",
               "ladakh":"Ladakh",
               "lakshadweep":"Lakshadweep",
               "madhya-pradesh":"Madhya Pradesh",
               "maharashtra":"Maharashtra",
               "manipur":"Manipur",
               "meghalaya":"Meghalaya",
               "mizoram":"Mizoram",
               "nagaland":"Nagaland",
               "odisha":"Odisha",
               "puducherry":"Puducherry",
               "punjab":"Punjab",
               "rajasthan":"Rajasthan",
               "sikkim":"Sikkim",
               "tamil-nadu":"Tamil Nadu",
               "telangana":"Telangana",
               "tripura":"Tripura",
               "uttar-pradesh":"Uttar Pradesh",
               "uttarakhand":"Uttarakhand",
               "west-bengal":"West Bengal"}

# %%
data_amount["State"] = data_amount["State"].apply(lambda x:state_names[x])

# %%
data_amount
# Out:
#                                        State  Transaction_Amount
# 0                          Andaman & Nicobar         28446581857
# 1                             Andhra Pradesh      16339842112586
# 2                          Arunachal Pradesh        106743520036
# 3                                      Assam       1548293213867
# 4                                      Bihar       7914668793994
# 5                                 Chandigarh        188038858249
# 6                               Chhattisgarh       2102595782665
# 7   Dadra and Nagar Haveli and Daman and Diu         83707688653
# 8                                      Delhi       6384975701344
# 9                                        Goa        234075461304
# 10                                   Gujarat       4868271186175
# 11                                   Haryana       4517875241440
# 12                          Himachal Pradesh        369315630618
# ...

# %%
import plotly.express as px
fig = px.choropleth(
            data_amount,
            geojson="https://gist.githubusercontent.com/jbrobst/56c13bbbf9d97d187fea01ca62ea5112/raw/e388c4cae20aa53cb5090210a42ebb9b765c0a36/india_states.geojson",
            featureidkey='properties.ST_NM',
            locations='State',
            color='Transaction_Amount',
            color_continuous_scale=px.colors.diverging.BrBG
        )

fig.update_geos(fitbounds="locations", visible=False)
# Add a title to the graph
fig.update_layout(title='Choropleth Map of Transaction Amount by State')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##**Break the loop**

# %%
df = pd.read_csv("Aggregated_transactions.csv")

# %%
df
# Out:
#       Unnamed: 0        State  Year  Quater          Transaction_type  \
# 0              0  lakshadweep  2018       1     Peer-to-peer payments
# 1              1  lakshadweep  2018       1  Recharge & bill payments
# 2              2  lakshadweep  2018       1         Merchant payments
# 3              3  lakshadweep  2018       1                    Others
# 4              4  lakshadweep  2018       2     Peer-to-peer payments
# ...          ...          ...   ...     ...                       ...
# 3949        3949      tripura  2023       2         Merchant payments
# 3950        3950      tripura  2023       2     Peer-to-peer payments
# 3951        3951      tripura  2023       2  Recharge & bill payments
# 3952        3952      tripura  2023       2        Financial Services
# 3953        3953      tripura  2023       2                    Others
#
#       Transaction_count  Transaction_Amount
# 0                   423             1860278
# ...

# %%
def us_dollars(number):
                    """Converts an integer number to US dollars.

                    Args:
                        number: An integer number.

                    Returns:
                        A string representing the number in US dollars, with two decimal places.
                    """
                    res = number//83.22
                    return "{:,.2f}".format(res)

# %%
uta = []
for i in df["Transaction_Amount"]:
  uta.append(np.log(i))

# %%
uta
# Out:
# [14.43623649688659,
#  11.02568615101038,
#  6.380122536899765,
#  8.749890955535259,
#  15.565948428724136,
#  12.774795410210066,
#  11.075474211004208,
#  9.119758993744945,
#  8.237479288613633,
#  12.769113988119456,
#  15.161303185774813,
#  12.476401264010747,
#  5.963579343618446,
#  9.025455532779063,
#  15.183143879928215,
#  12.614792451358834,
#  11.45153930325588,
#  9.795790977080754,
#  17.02731000421944,
#  13.883364514467038,
#  13.85493605783963,
#  9.675896626294639,
#  11.437285550761484,
#  14.372434153771833,
#  16.993415085500445,
#  14.237721993652212,
#  9.619266151713328,
#  11.526493008191766,
#  17.615409515418424,
#  14.55453939135802,
#  15.219457933696042,
#  9.903187507527125,
#  11.66462457071542,
#  17.346041989887816,
#  14.346307618306767,
#  14.827244915283943,
#  11.829391767915634,
#  11.200595445597218,
#  17.698946087660506,
#  14.658189194717368,
#  15.16055522894851,
#  10.55252609347001,
#  11.914081301490294,
#  17.69607856129972,
# ...

# %%
df["Updated_Transaction_Amount"] = uta

# %%
utc = []
for i in df["Transaction_count"]:
  utc.append(np.log(i))

# %%
utc
# Out:
# [6.0473721790462776,
#  5.834810737062605,
#  1.6094379124341003,
#  2.0794415416798357,
#  7.181591944611865,
#  6.620073206530356,
#  3.7376696182833684,
#  1.791759469228055,
#  2.9444389791664403,
#  6.674561391814426,
#  6.535241271013659,
#  4.969813299576001,
#  1.791759469228055,
#  2.3978952727983707,
#  6.734591659972948,
#  6.633318433280377,
#  4.465908118654584,
#  2.70805020110221,
#  8.279443487712665,
#  8.172164452111904,
#  7.337587743538596,
#  2.9444389791664403,
#  3.828641396489095,
#  8.612321536507814,
#  8.31115254800169,
#  7.463363045520021,
#  3.367295829986474,
#  3.784189633918261,
#  8.875426919818963,
#  8.585785982881848,
#  7.962763930168115,
#  3.295836866004329,
#  4.127134385045092,
#  8.645938147306799,
#  8.547334348328224,
#  7.803843303538772,
#  3.871201010907891,
#  3.4657359027997265,
#  8.976262255609193,
#  8.58185670474196,
#  8.022240916806537,
#  3.6635616461296463,
#  4.143134726391533,
#  9.046762057999363,
#  8.58783803098557,
# ...

# %%
df["Updated_Transaction_count"] = utc

# %%
df
# Out:
#       Unnamed: 0        State  Year  Quater          Transaction_type  \
# 0              0  lakshadweep  2018       1     Peer-to-peer payments
# 1              1  lakshadweep  2018       1  Recharge & bill payments
# 2              2  lakshadweep  2018       1         Merchant payments
# 3              3  lakshadweep  2018       1                    Others
# 4              4  lakshadweep  2018       2     Peer-to-peer payments
# ...          ...          ...   ...     ...                       ...
# 3949        3949      tripura  2023       2         Merchant payments
# 3950        3950      tripura  2023       2     Peer-to-peer payments
# 3951        3951      tripura  2023       2  Recharge & bill payments
# 3952        3952      tripura  2023       2        Financial Services
# 3953        3953      tripura  2023       2                    Others
#
#       Transaction_count  Transaction_Amount  Updated_Transaction_Amount  \
# ...

# %%
df.to_csv("Aggregated_transactions.csv",index = False)

# %% [markdown]
# ##**Quarter wise data collection**

# %%
df_grouped = df.groupby(['Year', 'Quater'])
Demo = list(df_grouped)

# %%
year_and_quarter_group = []
for i in range(0,len(Demo)-4+1,4):
  year_and_quarter_group.append(Demo[i:i+4])

# %%
year_and_quarter_group.extend([Demo[-2],Demo[-1]])

# %%
Q1_2018 = year_and_quarter_group[0][0][1]
Q1_2018.to_csv("Q1_2018.csv")

# %%
Q1_2018
# Out:
#       Unnamed: 0           State  Year  Quater          Transaction_type  \
# 0              0     lakshadweep  2018       1     Peer-to-peer payments
# 1              1     lakshadweep  2018       1  Recharge & bill payments
# 2              2     lakshadweep  2018       1         Merchant payments
# 3              3     lakshadweep  2018       1                    Others
# 104          104  andhra-pradesh  2018       1  Recharge & bill payments
# ...          ...             ...   ...     ...                       ...
# 3844        3844         tripura  2018       1  Recharge & bill payments
# 3845        3845         tripura  2018       1     Peer-to-peer payments
# 3846        3846         tripura  2018       1        Financial Services
# 3847        3847         tripura  2018       1         Merchant payments
# 3848        3848         tripura  2018       1                    Others
#
#       Transaction_count  Transaction_Amount  Updated_Transaction_Amount  \
# ...

# %%
data_amount = Q1_2018.groupby(['State'])['Transaction_Amount'].sum().reset_index()

# %%
data_amount
# Out:
#                                  State  Transaction_Amount
# 0            andaman-&-nicobar-islands            14631759
# 1                       andhra-pradesh         11996276389
# 2                    arunachal-pradesh            92387333
# 3                                assam          1157804453
# 4                                bihar          6045758169
# 5                           chandigarh           613435419
# 6                         chhattisgarh          2149155555
# 7   dadra-&-nagar-haveli-&-daman-&-diu           175658381
# 8                                delhi         11211503804
# 9                                  goa           303856740
# 10                             gujarat          7577982252
# 11                             haryana          6793511513
# 12                    himachal-pradesh           628737803
# 13                     jammu-&-kashmir          1005371236
# 14                           jharkhand          2374186388
# ...

# %%
Q2_2018 = year_and_quarter_group[0][1][1]
Q2_2018.to_csv("Q2_2018.csv")

# %%
Q3_2018 = year_and_quarter_group[0][2][1]
Q3_2018.to_csv("Q3_2018.csv")

# %%
Q4_2018 = year_and_quarter_group[0][3][1]
Q4_2018.to_csv("Q4_2018.csv")

# %%
Q1_2019 = year_and_quarter_group[1][0][1]
Q1_2019.to_csv("Q1_2019.csv")

# %%
Q2_2019 = year_and_quarter_group[1][1][1]
Q2_2019.to_csv("Q2_2019.csv")

# %%
Q3_2019 = year_and_quarter_group[1][2][1]
Q3_2019.to_csv("Q3_2019.csv")

# %%
Q4_2019 = year_and_quarter_group[1][3][1]
Q4_2019.to_csv("Q4_2019.csv")

# %%
Q1_2020 = year_and_quarter_group[2][0][1]
Q1_2020.to_csv("Q1_2020.csv")

# %%
Q2_2020 = year_and_quarter_group[2][1][1]
Q2_2020.to_csv("Q2_2020.csv")

# %%
Q3_2020 = year_and_quarter_group[2][2][1]
Q3_2020.to_csv("Q3_2020.csv")

# %%
Q4_2020 = year_and_quarter_group[2][3][1]
Q4_2020.to_csv("Q4_2020.csv")

# %%
Q1_2021 = year_and_quarter_group[3][0][1]
Q1_2021.to_csv("Q1_2021.csv")

# %%
Q2_2021 = year_and_quarter_group[3][1][1]
Q2_2021.to_csv("Q2_2021.csv")

# %%
Q3_2021 = year_and_quarter_group[3][2][1]
Q3_2021.to_csv("Q3_2021.csv")

# %%
Q4_2021 = year_and_quarter_group[3][3][1]
Q4_2021.to_csv("Q4_2021.csv")

# %%
Q1_2022 = year_and_quarter_group[4][0][1]
Q1_2022.to_csv("Q1_2022.csv")

# %%
Q2_2022 = year_and_quarter_group[4][1][1]
Q2_2022.to_csv("Q2_2022.csv")

# %%
Q3_2022 = year_and_quarter_group[4][2][1]
Q3_2022.to_csv("Q3_2022.csv")

# %%
Q4_2022 = year_and_quarter_group[4][3][1]
Q4_2022.to_csv("Q4_2022.csv")

# %%
Q1_2023 = year_and_quarter_group[-2][1]
Q1_2023.to_csv("Q1_2023.csv")

# %%
Q2_2023 = year_and_quarter_group[-1][1]
Q2_2023.to_csv("Q2_2023.csv")

# %%
Q1_2018
# Out:
#       Unnamed: 0           State  Year  Quater          Transaction_type  \
# 0              0     lakshadweep  2018       1     Peer-to-peer payments
# 1              1     lakshadweep  2018       1  Recharge & bill payments
# 2              2     lakshadweep  2018       1         Merchant payments
# 3              3     lakshadweep  2018       1                    Others
# 104          104  andhra-pradesh  2018       1  Recharge & bill payments
# ...          ...             ...   ...     ...                       ...
# 3844        3844         tripura  2018       1  Recharge & bill payments
# 3845        3845         tripura  2018       1     Peer-to-peer payments
# 3846        3846         tripura  2018       1        Financial Services
# 3847        3847         tripura  2018       1         Merchant payments
# 3848        3848         tripura  2018       1                    Others
#
#       Transaction_count  Transaction_Amount  Updated_Transaction_Amount  \
# ...

# %%
tot_trans_count = Q1_2018["Transaction_count"].sum()

# %%
def convert(n):
  numbers = "{:,}".format(n)
  return numbers

# %%
tot_count = convert(tot_trans_count)

# %%
print("All PhonePe transactions (UPI + Cards + Wallets) = ",tot_count)
# Out:
# All PhonePe transactions (UPI + Cards + Wallets) =  134,425,599

# %%
tot_trans_amount = Q1_2018["Transaction_Amount"].sum()

# %%
amount = convert(tot_trans_amount)

# %%
print(f"Total payment value = \u20B9{amount} Cr")
# Out:
# Total payment value = ₹171,833,430,926 Cr

# %%
avg_trans_amount = Q1_2018["Transaction_Amount"].mean()

# %%
avg = int(avg_trans_amount)

# %%
avg_amount = convert(avg)

# %%
print(f"Avg. transaction value = \u20B9{avg_amount}")
# Out:
# Avg. transaction value = ₹959,963,301

# %%
count_by_trans_type = df.groupby(['Transaction_type'])['Transaction_count'].sum().reset_index()

# %%
count_by_trans_type
# Out:
#            Transaction_type  Transaction_count
# 0        Financial Services           81221368
# 1         Merchant payments        48861884393
# 2                    Others          213338362
# 3     Peer-to-peer payments        39258338265
# 4  Recharge & bill payments        11509019973

# %%
# Extract the transaction types from the DataFrame
transaction_types = count_by_trans_type['Transaction_type'].tolist()

# Print the transaction types
print(transaction_types)
# Out:
# ['Financial Services', 'Merchant payments', 'Others', 'Peer-to-peer payments', 'Recharge & bill payments']

# %%
# Extract the transaction amount from the DataFrame
transaction_count= count_by_trans_type['Transaction_count'].tolist()

# Print the transaction amount
print(transaction_count)
# Out:
# [81221368, 48861884393, 213338362, 39258338265, 11509019973]

# %%
dic_category = {}
for i in range(len(transaction_types)):
  dic_category[transaction_types[i]] = transaction_count[i]

# %%
dic_category
# Out:
# {'Financial Services': 81221368,
#  'Merchant payments': 48861884393,
#  'Others': 213338362,
#  'Peer-to-peer payments': 39258338265,
#  'Recharge & bill payments': 11509019973}

# %%
print(f"""categories:
        {transaction_types[0]} = {transaction_count[0]}

        {transaction_types[1]} = {transaction_count[1]}

        {transaction_types[3]} = {transaction_count[3]}

        {transaction_types[4]} = {transaction_count[4]}

        {transaction_types[2]} = {transaction_count[2]}
      """)
# Out:
# categories:
#         Financial Services = 81221368
#
#         Merchant payments = 48861884393
#
#         Peer-to-peer payments = 39258338265
#
#         Recharge & bill payments = 11509019973
#
#         Others = 213338362

# %%
df = pd.read_csv("Aggregate_Users.csv")

# %%
df
# Out:
#      Unnamed: 0        State  Year  Quater  registered_users    Brand   count  \
# 0             0  lakshadweep  2018       1               501  Samsung     102
# 1             1  lakshadweep  2018       2               686   Xiaomi     147
# 2             2  lakshadweep  2018       4              1156   Xiaomi     245
# 3             3  lakshadweep  2018       3               918   Xiaomi     195
# 4             4  lakshadweep  2021       1              4577     Vivo    1032
# ..          ...          ...   ...     ...               ...      ...     ...
# 607         607      tripura  2019       3            245456   Xiaomi   61894
# 608         608      tripura  2020       1            299962   Xiaomi   75081
# 609         609      tripura  2020       2            336666   Xiaomi   83763
# 610         610      tripura  2020       4            409110   Xiaomi  101066
# 611         611      tripura  2020       3            376731   Xiaomi   93468
#
# ...

# %%
df_grouped = df.groupby(['Year', 'Quater'])
Demo = list(df_grouped)

# %%
year_and_quarter_group = []
for i in range(0,len(Demo)-4+1,4):
  year_and_quarter_group.append(Demo[i:i+4])

# %%
year_and_quarter_group.extend([Demo[-2],Demo[-1]])

# %%
Q1_user_2018 = year_and_quarter_group[0][0][1]

# %%
Q1_user_2018.to_csv("Q1_user_2018.csv")

# %%
Q2_user_2018 = year_and_quarter_group[0][1][1]
Q2_user_2018.to_csv("Q2_user_2018.csv")

# %%
Q3_user_2018 = year_and_quarter_group[0][2][1]
Q3_user_2018.to_csv("Q3_user_2018.csv")

# %%
Q4_user_2018 = year_and_quarter_group[0][3][1]
Q4_user_2018.to_csv("Q4_user_2018.csv")

# %%
Q1_user_2019 = year_and_quarter_group[1][0][1]
Q1_user_2019.to_csv("Q1_user_2019.csv")

# %%
Q2_user_2019 = year_and_quarter_group[1][1][1]
Q2_user_2019.to_csv("Q2_user_2019.csv")

# %%
Q3_user_2019 = year_and_quarter_group[1][2][1]
Q3_user_2019.to_csv("Q3_user_2019.csv")

# %%
Q4_user_2019 = year_and_quarter_group[1][3][1]
Q4_user_2019.to_csv("Q4_user_2019.csv")

# %%
Q1_user_2020 = year_and_quarter_group[2][0][1]
Q1_user_2020.to_csv("Q1_user_2020.csv")

# %%
Q2_user_2020 = year_and_quarter_group[2][1][1]
Q2_user_2020.to_csv("Q2_user_2020.csv")

# %%
Q3_user_2020 = year_and_quarter_group[2][2][1]
Q3_user_2020.to_csv("Q3_user_2020.csv")

# %%
Q4_user_2020 = year_and_quarter_group[2][3][1]
Q4_user_2020.to_csv("Q4_user_2020.csv")

# %%
Q1_user_2021 = year_and_quarter_group[3][0][1]
Q1_user_2021.to_csv("Q1_user_2021.csv")

# %%
Q2_user_2021 = year_and_quarter_group[3][1][1]
Q2_user_2021.to_csv("Q2_user_2021.csv")

# %%
Q3_user_2021 = year_and_quarter_group[3][2][1]
Q3_user_2021.to_csv("Q3_user_2021.csv")

# %%
Q4_user_2021 = year_and_quarter_group[3][3][1]
Q4_user_2021.to_csv("Q4_user_2021.csv")

# %%
Q1_user_2022 = year_and_quarter_group[-1][1]
Q1_user_2022.to_csv("Q1_user_2022.csv")

# %%
Q1_user_2022
# Out:
#      Unnamed: 0                               State  Year  Quater  \
# 8             8                         lakshadweep  2022       1
# 25           25                      andhra-pradesh  2022       1
# 42           42                               delhi  2022       1
# 59           59                             manipur  2022       1
# 76           76                              sikkim  2022       1
# 93           93                               bihar  2022       1
# 110         110                         west-bengal  2022       1
# 127         127                             gujarat  2022       1
# 144         144                    himachal-pradesh  2022       1
# 161         161                          chandigarh  2022       1
# 178         178  dadra-&-nagar-haveli-&-daman-&-diu  2022       1
# 195         195                             haryana  2022       1
# 212         212           andaman-&-nicobar-islands  2022       1
# ...

# %%
year_and_quarter_group
# Out:
# [[((2018, 1),
#         Unnamed: 0                               State  Year  Quater  \
#    0             0                         lakshadweep  2018       1
#    17           17                      andhra-pradesh  2018       1
#    34           34                               delhi  2018       1
#    51           51                             manipur  2018       1
#    68           68                              sikkim  2018       1
#    85           85                               bihar  2018       1
#    102         102                         west-bengal  2018       1
#    119         119                             gujarat  2018       1
#    136         136                    himachal-pradesh  2018       1
#    153         153                          chandigarh  2018       1
#    170         170  dadra-&-nagar-haveli-&-daman-&-diu  2018       1
#    187         187                             haryana  2018       1
# ...

# %%
df = pd.read_csv("Aggregated_transactions.csv")

# %%
grouped_df = df.groupby(['State', 'Year'])['Transaction_Amount'].max().reset_index()

# %%
grouped_df
# Out:
#    Year  Transaction_Amount
# 0  2018       1623045396048
# 1  2019       6276688132817
# 2  2020      14641161977712
# 3  2021      34598699686820
# 4  2022      64266332910550
# 5  2023      43432452307247
